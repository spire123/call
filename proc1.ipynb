# %%
import pandas as pd

data=pd.read_csv("tested.csv")

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]>

# %%
data.iloc[3:4,6:7]
# Out:
#    SibSp
# 3      0

# %%
df = pd.DataFrame(data)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
df['Gender'] = df['Gender'].map({'M': 0,
                                 'F': 1, }).astype(float)
 df
# Out:
#   File "C:\Users\abhij\AppData\Local\Temp\ipykernel_12676\3211807257.py", line 3
#     df
#     ^
# IndentationError: unexpected indent

# %%
df['Gender'] = df['Gender'].map({'M': 0, 'F': 1, }).astype(float)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12676\1645934650.py in <module>
# ----> 1 df['Gender'] = df['Gender'].map({'M': 0, 'F': 1, }).astype(float)
#       2
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Gender'

# %%
df['Sex'] = df['Sex'].map({'M': 0,
                                 'F': 1, }).astype(float)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James  NaN  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  NaN  47.0      1      0
# 2                       Myles, Mr. Thomas Francis  NaN  62.0      0      0
# 3                                Wirz, Mr. Albert  NaN  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  NaN  22.0      1      1
# ..                                            ...  ...   ...    ...    ...
# 413                            Spector, Mr. Woolf  NaN   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  NaN  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen  NaN  38.5      0      0
# 416                           Ware, Mr. Frederick  NaN   NaN      0      0
# 417                      Peter, Master. Michael J  NaN   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
# Filter top scoring students
df = df[df['Age'] >= 45]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 2            894         0       2
# 11           903         0       1
# 13           905         0       2
# 14           906         1       1
# ..           ...       ...     ...
# 387         1279         0       2
# 391         1283         1       1
# 393         1285         0       2
# 397         1289         1       1
# 407         1299         0       1
#
#                                                   Name  Sex   Age  SibSp  \
# 1                     Wilkes, Mrs. James (Ellen Needs)  NaN  47.0      1
# 2                            Myles, Mr. Thomas Francis  NaN  62.0      0
# 11                          Jones, Mr. Charles Cresson  NaN  46.0      0
# 13                                Howard, Mr. Benjamin  NaN  63.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  NaN  47.0      1
# ..                                                 ...  ...   ...    ...
# 387                                    Ashby, Mr. John  NaN  57.0      0
# 391     Lines, Mrs. Ernest H (Elizabeth Lindsey James)  NaN  51.0      0
# 393                               Gilbert, Mr. William  NaN  47.0      0
# 397  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...  NaN  48.0      1
# 407                         Widener, Mr. George Dunton  NaN  50.0      1
#
#      Parch       Ticket      Fare Cabin Embarked
# 1        0       363272    7.0000   NaN        S
# 2        0       240276    9.6875   NaN        Q
# 11       0          694   26.0000   NaN        S
# 13       0        24065   26.0000   NaN        S
# 14       0  W.E.P. 5734   61.1750   E31        S
# ..     ...          ...       ...   ...      ...
# 387      0       244346   13.0000   NaN        S
# 391      1     PC 17592   39.4000   D28        S
# 393      0   C.A. 30769   10.5000   NaN        S
# 397      1        13567   79.2000   B41        C
# 407      1       113503  211.5000   C80        C
#
# [61 rows x 12 columns]

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name   Sex    Age  SibSp  Parch  Ticket  \
# 1          False     False   False  False  True  False  False  False   False
# 2          False     False   False  False  True  False  False  False   False
# 11         False     False   False  False  True  False  False  False   False
# 13         False     False   False  False  True  False  False  False   False
# 14         False     False   False  False  True  False  False  False   False
# ..           ...       ...     ...    ...   ...    ...    ...    ...     ...
# 387        False     False   False  False  True  False  False  False   False
# 391        False     False   False  False  True  False  False  False   False
# 393        False     False   False  False  True  False  False  False   False
# 397        False     False   False  False  True  False  False  False   False
# 407        False     False   False  False  True  False  False  False   False
#
#       Fare  Cabin  Embarked
# 1    False   True     False
# 2    False   True     False
# 11   False   True     False
# 13   False   True     False
# 14   False  False     False
# ..     ...    ...       ...
# 387  False   True     False
# 391  False  False     False
# 393  False   True     False
# 397  False  False     False
# 407  False  False     False
#
# [61 rows x 12 columns]

# %%
#remokving missing Value
df.dropna()
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#unique values from column
df.Locality.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12676\2250208787.py in <module>
#       1 #unique values from column
# ----> 2 df.Locality.unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Locality'

# %%
#unique values from column
df.Sex.unique()
# Out:
# array([nan])
